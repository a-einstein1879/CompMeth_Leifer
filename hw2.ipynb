# %%
import hw2 as hw2
hw2.problem1()
# Out:
# 0

# %%
import hw2 as hw2
hw2.problem2()
# Out:
# 0

# %%
import hw2 as hw2
hw2.problem3()
# Out:
# Checking for limits -2 < X < 2, -2 < Y < 2 with the step dx = 0.00, dy = 0.00
# nx = 4001, ny = 4001
# Elapsed time 120.70 sec
# 0
